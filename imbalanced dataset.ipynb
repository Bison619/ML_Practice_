# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('Dataset/credit_data.csv')

# %% [markdown]
# <h2>Data Analyzation</h2>

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.value_counts("Class")
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# 0 -- legit
# 1 -- fraud

# %% [markdown]
# <h2>Picking the 0s and 1s</h2>

# %%
imbalanced = data[data.Class == 0]
y = data[data.Class == 1]

# %%
imbalanced.shape
# Out:
# (284315, 31)

# %% [markdown]
# <h2>Taking random 492 value to balance out the data</h2>

# %%
balanced = imbalanced.sample(n=492)

# %%
balanced.shape
# Out:
# (492, 31)

# %%
data2 = pd.concat([balanced, y], axis=0)

# %%
data2.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 259760  159260.0  2.189757 -1.663723  0.040048 -1.581248 -1.853630  0.032107
# 100185   67444.0 -1.138322  0.085699  3.145596 -1.417040 -1.604292 -0.035245
# 210833  138139.0 -1.462192  0.964229  0.092672 -0.906416 -0.407730 -1.381578
# 195245  130965.0  1.778661 -0.263032  0.919062  4.024988 -0.434436  2.161918
# 167853  118924.0 -0.748001  1.021897  1.101208 -0.108153  0.651587  0.543523
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 259760 -1.855467  0.116155 -0.888309  ... -0.100279  0.251960  0.279721
# 100185 -0.586014  0.205161  0.817620  ...  0.037014  0.738928 -0.375045
# 210833  0.502616  0.351793 -2.318549  ... -0.211023 -0.350941 -0.359437
# 195245 -1.370207  0.566137  0.876731  ...  0.062019  0.626037  0.099404
# 167853  0.244027  0.096773  0.003462  ...  0.119267  0.432614 -0.561629
#
# ...

# %% [markdown]
# <h2>Balanced</h2>

# %%
data2.value_counts('Class')
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64
