# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('youtube_channel_real_performance_analytics.csv')

# %%
print(df.isnull().sum())
print(df.duplicated())
print(df.info())
plt.style.use('fivethirtyeight')
# Out:
# ID                         0
# Video Duration             0
# Video Publish Time         0
# Days Since Publish         0
# Day                        0
#                           ..
# Watch Time (hours)         0
# Subscribers                0
# Estimated Revenue (USD)    0
# Impressions                0
# Video Thumbnail CTR (%)    0
# Length: 70, dtype: int64
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 359    False
# 360    False
# 361    False
# 362    False
# 363    False
# Length: 364, dtype: bool
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 70 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  364 non-null    int64
#  1   Video Duration                      364 non-null    float64
#  2   Video Publish Time                  364 non-null    object
# ...

# %%
df.describe()
# Out:
#                ID  Video Duration  Days Since Publish         Day       Month  \
# count  364.000000      364.000000          364.000000  364.000000  364.000000
# mean   181.500000      664.239011            8.406593   15.807692    6.642857
# std    105.221988      330.646183           15.371239    8.924004    3.421521
# min      0.000000        9.000000            0.000000    1.000000    1.000000
# 25%     90.750000      496.000000            3.000000    8.000000    4.000000
# 50%    181.500000      613.000000            5.000000   16.000000    7.000000
# 75%    272.250000      786.500000            9.000000   23.000000   10.000000
# max    363.000000     2311.000000          260.000000   31.000000   12.000000
#
#               Year  Revenue per 1000 Views (USD)  \
# count   364.000000                    364.000000
# mean   2018.736264                      0.112283
# std       2.530629                      0.179668
# min    2016.000000                      0.000000
# ...

# %%
df.head()
# Out:
#    ID  Video Duration   Video Publish Time  Days Since Publish  Day  Month  \
# 0   0           201.0  2016-06-02 00:00:00                   0    2      6
# 1   1           391.0  2016-06-10 00:00:00                   8   10      6
# 2   2           133.0  2016-06-14 00:00:00                   4   14      6
# 3   3            14.0  2016-06-29 00:00:00                  15   29      6
# 4   4            45.0  2016-07-01 00:00:00                   2    1      7
#
#    Year Day of Week  Revenue per 1000 Views (USD)  \
# 0  2016    Thursday                         0.024
# 1  2016      Friday                         0.056
# 2  2016     Tuesday                         0.014
# 3  2016   Wednesday                         0.004
# 4  2016      Friday                         0.000
#
#    Monetized Playbacks (Estimate)  ...  Watched (Not Skipped) (%)  \
# 0                           723.0  ...                        0.0
# 1                           727.0  ...                        0.0
# ...

# %%
df['Video Publish Time'] = pd.to_datetime(df['Video Publish Time'])

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x ='Views', y='Subscribers' ,hue='Year', data=df, palette='viridis')
# plt.xticks(ticks=range(0,int(df['Views'].max())+1, 5000))
plt.title('View and subs per year')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(x ='Views', data=df,hue='Day of Week', palette='Set2')
plt.xticks(ticks=range(0,int(df['Views'].max())+1, 100000))
plt.title('Views countplot')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x ='Revenue per 1000 Views (USD)', data=df, showmeans = True)
# plt.xticks(ticks=range(0,int(df['Views'].max())+1, 5000))
plt.title('Revenue per year')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x ='Day of Week',y='Views', data=df)
plt.title('Views per week days')
plt.show()

# %%
custom_palette = sns.color_palette("Paired", 12)
sns.palplot(custom_palette)

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x ='Year',y='Views', data=df, color = 'red')
plt.title('Views per year')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.swarmplot(x ='Day of Week',y='Video Duration', data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x ='Watch Time (hours)',y='Views',hue = 'Month', data=df, palette='viridis')
plt.title('Views per year')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(x ='Subscribers',y= 'Average View Duration', data=df)
plt.xticks(ticks=range(0,int(df['Subscribers'].max())+1, 500))
plt.yticks(ticks=range(0,int(df['Average View Duration'].max())+1, 100))
plt.title('Views countplot')
plt.show()
