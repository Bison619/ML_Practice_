# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x= np.linspace(0,10,50)
y= x**2
z = np.sin(x)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,z)
plt.show()

# %%
plt.plot(x,np.sin(y), 'rx')
plt.plot(x,z, 'g--')
plt.show()
